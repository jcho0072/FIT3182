# %%
import pandas as pd
from kafka3 import KafkaProducer
from time import sleep
import json

# Kafka setup
hostip = "host.docker.internal"
producer = KafkaProducer(
    bootstrap_servers=[f'{hostip}:9092'],
    api_version=(0, 10)
)

df = pd.read_csv("/home/student/work/ass2/data/camera_event_B.csv")

# Kafka topic for Producer B
topic = "camera_event_b"
batch_interval = 5  # seconds

# Send batches by batch_id
for batch_id in sorted(df['batch_id'].unique()):
    batch = df[df['batch_id'] == batch_id]
    for _, row in batch.iterrows():
        # Format timestamp properly
        row['timestamp'] = pd.to_datetime(row['timestamp']).isoformat()
        
        # Convert to dict and append producer metadata
        msg = row.to_dict()
        msg['producer'] = 'B'
        msg['producer_timestamp'] = pd.Timestamp.now().isoformat()
       
        
        # Send message
        producer.send(topic, value=json.dumps(msg).encode('utf-8'))
        
    producer.flush()
    print(f"Sent batch {batch_id}")
    sleep(batch_interval)
# Out:
# Sent batch 1
# Sent batch 2
# Sent batch 3
# Sent batch 4
# Sent batch 5
# Sent batch 6
# Sent batch 7
# Sent batch 8
# Sent batch 9
# Sent batch 10
# Sent batch 11
# Sent batch 12
# Sent batch 13
# Sent batch 14
# Sent batch 15
# Sent batch 16
# Sent batch 17
# Sent batch 18
# Sent batch 19
# Sent batch 20
# Sent batch 21
# Sent batch 22
# Sent batch 23
# Sent batch 24
# Sent batch 25
# Sent batch 26
# Sent batch 27
# Sent batch 28
# Sent batch 29
# Sent batch 30
# Sent batch 31
# Sent batch 32
# Sent batch 33
# Sent batch 34
# Sent batch 35
# Sent batch 36
# Sent batch 37
# Sent batch 38
# Sent batch 39
# Sent batch 40
# Sent batch 41
# Sent batch 42
# Sent batch 43
# Sent batch 44
# Sent batch 45
# Sent batch 46
# Sent batch 47
# Sent batch 48
# Sent batch 49
# Sent batch 50
# Sent batch 51
# Sent batch 52
# Sent batch 53
# Sent batch 54
# Sent batch 55
# Sent batch 56
# Sent batch 57
# Sent batch 58
# Sent batch 59
# Sent batch 60
# Sent batch 61
# Sent batch 62
# Sent batch 63
# Sent batch 64
# Sent batch 65
# Sent batch 66
# Sent batch 67
# Sent batch 68
# Sent batch 69
# Sent batch 70
# Sent batch 71
# Sent batch 72
# Sent batch 73
# Sent batch 74
# Sent batch 75
# Sent batch 76
# Sent batch 77
# Sent batch 78
# Sent batch 79
# Sent batch 80
# Sent batch 81
# Sent batch 82
# Sent batch 83
# Sent batch 84
# Sent batch 85
# Sent batch 86
# Sent batch 87
# Sent batch 88
# Sent batch 89
# Sent batch 90
# Sent batch 91
# Sent batch 92
# Sent batch 93
# Sent batch 94
# Sent batch 95
# Sent batch 96
# Sent batch 97
# Sent batch 98
# Sent batch 99
# Sent batch 100
# Sent batch 101
# Sent batch 102
# Sent batch 103
# Sent batch 104
# Sent batch 105
# Sent batch 106
# Sent batch 107
# Sent batch 108
# Sent batch 109
# Sent batch 110
# Sent batch 111
# Sent batch 112
# Sent batch 113
# Sent batch 114
# Sent batch 115
# Sent batch 116
# Sent batch 117
# Sent batch 118
# Sent batch 119
# Sent batch 120
# Sent batch 121
# Sent batch 122
# Sent batch 123
# Sent batch 124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 37
#      35 producer.flush()
#      36 print(f"Sent batch {batch_id}")
# ---> 37 sleep(batch_interval)
#
# KeyboardInterrupt:
